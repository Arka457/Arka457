# %% [markdown]
# <a href="https://colab.research.google.com/github/Arka457/Arka457/blob/main/Arka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("studyopedia sample Python Program.....")
# Out:
# studyopedia sample Python Programme.....

# %% [markdown]
# sample program  to sum two numbers in python

# %%
a = 40
b = 8
c = a + b
print("sum = ",c)
# Out:
# sum =  48
